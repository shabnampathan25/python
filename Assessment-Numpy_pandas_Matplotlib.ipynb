# %% [markdown]
# # Module: 8 _NumPy, Pandas, Matplotlib

# %% [markdown]
# ## ASSESSMENT 1

# %% [markdown]
# ### 1) Import pandas and read in the banklist.csv file into a dataframe called banks.

# %%
import pandas as pd

df = pd.read_csv("C://Users//Acer//Downloads//banklist.csv")
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %% [markdown]
# ### 2) Show the head of the dataframe.

# %%
df.head()
# or
df.head(5)
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %% [markdown]
# ### 3) What are the column names?

# %%
df.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %% [markdown]
# ### 4) How many States (ST) are represented in this data set?

# %%
df.ST.nunique()

#or

df["ST"].nunique()
# Out:
# 44

# %% [markdown]
# ### 5) Get a list or array of all the states in the data set.

# %%
df.ST.unique()
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %% [markdown]
# ### 6) What are the top 5 states with the most failed banks?

# %%
x = df["ST"].value_counts()
x
# Out:
# ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# WA    19
# AZ    16
# MO    16
# MI    14
# NV    12
# TX    12
# WI    11
# PA    10
# SC    10
# CO    10
# MD    10
# KS     9
# OH     8
# UT     8
# OK     7
# TN     7
# NC     7
# NJ     7
# AL     7
# OR     6
# VA     5
# NY     5
# PR     4
# AR     4
# LA     4
# IN     3
# NM     3
# NE     3
# MS     2
# CT     2
# IA     2
# KY     2
# ID     2
# MA     1
# SD     1
# WY     1
# WV     1
# NH     1
# HI     1
# Name: count, dtype: int64

# %%
x.head()
# Out:
# ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# Name: count, dtype: int64

# %% [markdown]
# ### 7) What are the top 5 acquiring institutions?

# %%
df['Acquiring Institution'].head()
# Out:
# 0              United Fidelity Bank, fsb
# 1    First-Citizens Bank & Trust Company
# 2                           Whitney Bank
# 3                      Cache Valley Bank
# 4                    State Bank of Texas
# Name: Acquiring Institution, dtype: object

# %% [markdown]
# ### 8) How many banks has the State Bank of Texas acquired? How many of them were actually in Texas?

# %%
state_bank_acquisitions = df[df['Acquiring Institution'] == 'State Bank of Texas']
state_bank_acquisitions
# Out:
#                                  Bank Name     City  ST   CERT  \
# 4            Seaway Bank and Trust Company  Chicago  IL  19328
# 21   The National Republic Bank of Chicago  Chicago  IL    916
# 450         Millennium State Bank of Texas   Dallas  TX  57667
#
#     Acquiring Institution Closing Date Updated Date
# 4     State Bank of Texas    27-Jan-17    18-May-17
# 21    State Bank of Texas    24-Oct-14     6-Jan-16
# 450   State Bank of Texas     2-Jul-09    26-Oct-12

# %%
total_acquired = state_bank_acquisitions.shape[0]
total_acquired
# Out:
# 3

# %%
acquired_in_texas = state_bank_acquisitions[state_bank_acquisitions['ST'] == 'TX'].shape[0]
acquired_in_texas
# Out:
# 1

# %% [markdown]
# ### 9) What is the most common city in California for a bank to fail in?

# %%
california_banks = df[df['ST'] == 'CA']
california_banks
# Out:
#                                     Bank Name              City  ST   CERT  \
# 20     Frontier Bank, FSB D/B/A El Paseo Bank       Palm Desert  CA  34738
# 90                  Palm Desert National Bank       Palm Desert  CA  23632
# 131      Citizens Bank of Northern California       Nevada City  CA  33983
# 182                  San Luis Trust Bank, FSB   San Luis Obispo  CA  34783
# 183                          Charter Oak Bank              Napa  CA  57855
# 186                      Canyon National Bank      Palm Springs  CA  34692
# 218            First Vietnamese American Bank       Westminster  CA  57885
# 220                   Western Commercial Bank    Woodland Hills  CA  58087
# 243                        Sonoma Valley Bank            Sonoma  CA  27259
# 244                           Los Padres Bank           Solvang  CA  32165
# 245                      Butte Community Bank             Chico  CA  33219
# ...

# %%
most_common_city = california_banks['City'].value_counts().idxmax()
most_common_city
# Out:
# 'Los Angeles'

# %%
failure_count = california_banks['City'].value_counts().max()
failure_count
# Out:
# 4

# %% [markdown]
# ## Assessment 2

# %% [markdown]
# ### Q 1: Develop a Line chart using the functionality of pandas to show how automobile sales fluctuate from year to year.

# %%
import matplotlib.pyplot as plt

df1 = pd.read_csv("C://Users//Acer//Downloads//historical_automobile_sales.csv")
df1
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
yearly_sales = df1.groupby("Year")["Automobile_Sales"].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(yearly_sales["Year"], yearly_sales["Automobile_Sales"], marker="o", linestyle="-", color="b")

plt.title("Yearly Automobile Sales Fluctuation", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Automobile Sales", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.xticks(yearly_sales["Year"], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q 2: Plot different lines for categories of vehicle type and analyze the trend to answer the question Is there a noticeable difference in sales trends between different vehicle types during recession periods?

# %%
recession_data = df1[df1["Recession"] == 1]

sales_by_vehicle_type = (
    recession_data.groupby(["Year", "Vehicle_Type"])["Automobile_Sales"]
    .sum()
    .reset_index()
)

sales_pivot = sales_by_vehicle_type.pivot(index="Year", columns="Vehicle_Type", values="Automobile_Sales")

plt.figure(figsize=(12, 8))
for vehicle_type in sales_pivot.columns:
    plt.plot(sales_pivot.index, sales_pivot[vehicle_type], marker="o", label=vehicle_type)

plt.title("Automobile Sales Trends by Vehicle Type During Recession Periods", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Automobile Sales", fontsize=12)
plt.legend(title="Vehicle Type")
plt.grid(True, linestyle="--", alpha=0.6)
plt.xticks(sales_pivot.index, rotation=45)
plt.tight_layout()
plt.show()

# %%
#or
sales_pivot = (
    df1[df1["Recession"] == 1]
    .groupby(["Year", "Vehicle_Type"])["Automobile_Sales"]
    .sum()
    .unstack("Vehicle_Type")
)

sales_pivot.plot(figsize=(12, 8), marker="o")

plt.title("Automobile Sales Trends by Vehicle Type During Recession Periods", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Automobile Sales", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="Vehicle Type")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q 3: Use the functionality of Seaborn Library to create a visualization to comparethe sales trend per vehicle type for a recession period with a non- recession period.

# %%
import seaborn as sns

df1['Date'] = pd.to_datetime(df1['Date'])
df1['Recession_Period'] = df1['Recession'].apply(lambda x: 'Recession' if x == 1 else 'Non-Recession')
plt.figure(figsize=(14, 8))
sns.lineplot(x='Date', y='Automobile_Sales', hue='Vehicle_Type', style='Recession_Period', markers=True, data=df1)
plt.title('Sales Trend per Vehicle Type: Recession vs Non-Recession Period')
plt.xlabel('Date')
plt.ylabel('Automobile Sales')
plt.xticks(rotation=45)
plt.legend(title='Vehicle Type & Period')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q 4: Now you want to compare the sales of different vehicle types during a recession and a non-recession period
# Hint: To visualize sales of different vehicles during recession and non- recession periods, you
# can use a bar chart. You will need to group Recession, Vehicle_Typefor average
# Automobile_Sales and then plot it. Make use of sns. bar plot (x=x, y=data = df))

# %%
grouped_data = df1.groupby(['Recession', 'Vehicle_Type'], as_index=False)['Automobile_Sales'].mean()

# Creating a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Vehicle_Type', y='Automobile_Sales', hue='Recession', data=grouped_data)

# Adding labels and title
plt.xlabel('Vehicle Type')
plt.ylabel('Average Automobile Sales')
plt.title('Comparison of Vehicle Sales During Recession and Non-Recession Periods')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
